# %%
import torchvision.transforms as transforms
import torchvision.models as models
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.optim as optim
import time
from torchcam.methods import GradCAM
from torchcam.utils import overlay_mask
from torchvision.transforms.functional import to_pil_image
import math

import glob
import cv2


from tqdm import tqdm
import pandas as pd

from customDataset import CustomDataset


# to solve matplot error
plt.ion()  # 대화형 모드 활성화


### GPU setting ###
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device == 'cuda':
    torch.cuda.manual_seed(777)
print(device)

#파이토치의 랜덤시드 고정
import random
torch.manual_seed(0)
random.seed(0)

### Data Preprocessiong ###
BATCH_SIZE = 256
custom_transforms = transforms.Compose([transforms.Resize((448,448)),
                                        # transforms.CenterCrop((128,512)),
                                        transforms.ToTensor()])

train_set = CustomDataset(mode = "train",
                          transform=custom_transforms)
test_set = CustomDataset(mode = "test",
                          transform=custom_transforms)
valid_set = CustomDataset(mode = "valid",
                          transform=custom_transforms)
print("num of each dataset : ", len(train_set), len(test_set), len(valid_set))


#std와 mean 구하기
def get_mean_std(imageFolder):
    meanRGB = [np.mean(image.numpy(), axis = (1,2)) for image,_ in imageFolder]
    stdRGB = [np.std(image.numpy(), axis = (1,2)) for image,_ in imageFolder]

    # 각 채널별의 평균 뽑기
    meanR = np.mean([m[0] for m in meanRGB])
    meanG = np.mean([m[1] for m in meanRGB])
    meanB = np.mean([m[2] for m in meanRGB])

    stdR = np.mean([s[0] for s in stdRGB])
    stdG = np.mean([s[1] for s in stdRGB])
    stdB = np.mean([s[2] for s in stdRGB])

    return [[meanR, meanG, meanB], [stdR, stdG, stdB]]


train_mean, train_std = get_mean_std(train_set)
test_mean, test_std = get_mean_std(test_set)
valid_mean, valid_std = get_mean_std(valid_set)

print(f"test mean ; {test_mean}")
print(f"test std : {test_std}")

# normalization
# normal_train_transform = transforms.Compose([transforms.ToTensor(),
#                                              transforms.Resize((448, 448)),
#                                              transforms.Normalize(train_mean, train_std)
# ])
# normal_test_transform = transforms.Compose([transforms.ToTensor(),
#                                             transforms.Resize((448, 448)),
#                                             transforms.Normalize(test_mean, test_std)
# ])
# normal_valid_transform = transforms.Compose([transforms.ToTensor(),
#                                             transforms.Resize((448, 448)),
#                                             transforms.Normalize(valid_mean, valid_std)
# ])
# train_set = CustomDataset(mode = "train",
#                           transform=normal_train_transform)
# test_set = CustomDataset(mode = "test",
#                           transform=normal_test_transform)
# valid_set = CustomDataset(mode = "valid",
#                           transform=normal_valid_transform)

train_loader = DataLoader(train_set, batch_size = BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=1, shuffle=False)
test_loader = DataLoader(test_set, batch_size = 1, shuffle=False)

img = train_set[0][0].permute(1, 2, 0).numpy()
plt.imshow(img)
plt.show()


### model ###
epoch = 50
lr = 0.01
model = models.resnet18(pretrained=True)

### transfer learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 50)
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr = lr)
lr_sche = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma= 0.1) # 50 step마다 0.5곱하기
criterion = nn.CrossEntropyLoss().to(device)

from torchsummary import summary
summary(model, input_size=(3, 448, 448), device=device)


start = time.time()
val_accuracy = 0.
best_accuracy = 0.
accuracy_his = []
model.train()
for epoch in tqdm(range(1, epoch+1)):
    avg_cost = 0.
    train_progress = 0
    for batch_idx, (x_train, y_train) in enumerate(train_loader):
        x_train, y_train = x_train.to(device), y_train.to(device)

        optimizer.zero_grad()
        prediction = model(x_train)
        cost = criterion(prediction, y_train)
        cost.backward()
        optimizer.step()

        avg_cost += cost.item()
        train_progress += len(x_train)

        print("Train epoch : {} [{}/{}], learning cost {:.2f}, avg cost {:.2f}".format(
            epoch, train_progress, len(train_loader.dataset),
            cost.item(),
            avg_cost / (batch_idx + 1)
        ))          

    with torch.no_grad():
        model.eval()
        correct = 0.
        cost = 0
        for batch_idx, (x_valid, y_valid) in enumerate(valid_loader):
            x_valid, y_valid = x_valid.to(device), y_valid.to(device)

            output = model(x_valid)
            prediction = torch.argmax(output, 1)
            cost += criterion(output, y_valid)

            correct += (prediction == y_valid).sum().item()

        val_accuracy = 100. * correct / len(valid_loader.dataset)
        accuracy_his.append(val_accuracy)
        print("Test accuracy : {:.2f}% [{}/{}] \t Test cost : {:.2f}"
                .format(val_accuracy, correct, len(valid_loader.dataset), cost/len(valid_loader.dataset)))
    
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        torch.save(model.state_dict(), 'model/al1_model.pth')
    lr_sche.step()


end = time.time()
elasped_time = end - start

print("Elasped Time : {}h, {}m, {}s"
      .format(int(elasped_time/3600),
              int(elasped_time/60),
              int(elasped_time%60)))
print('Finished Training')

# plot accuracy history
plt.plot(accuracy_his, label=f"Accuracy")
plt.title(f"Accuracy")
plt.show()



loaded_model = models.resnet18(pretrained=True)
num_features = loaded_model.fc.in_features
loaded_model.fc = nn.Linear(num_features, 50)
loaded_model.to(device)
loaded_model.load_state_dict(torch.load(f'model/al1_model.pth', weights_only=True))
cur_row = 0
cur_col = 0

# plot gradcam
col = math.ceil(math.sqrt(len(test_loader.dataset)))
row = col
# fig, axs = plt.subplots(row, col, constrained_layout=True, figsize=(18, 18))
fig, axs = plt.subplots(2, 2, constrained_layout=True, figsize=(18, 18))
print('start eval')

#with torch.no_grad():
loaded_model.eval()
correct = 0.
num = 0.
# confusion_matrix = np.zeros(shape=(50,50))
for batch_idx, data in enumerate(test_loader):
    x_test, y_test = data
    x_test = x_test.to(device)
    y_test = y_test.to(device)

    output = loaded_model(x_test)
    prediction = torch.argmax(output, 1)
    correct += (prediction == y_test).sum().item()

    if(batch_idx == 0):
    # gradcam
        with GradCAM(loaded_model) as cam_extractor:
            output = loaded_model(x_test)
            print(x_test.size())
            img = x_test.squeeze(0) # batch c h w -> c h w
            # heat map 출력
            activation_map = cam_extractor(output.squeeze(0).argmax().item(), output)
            # Resize the CAM and overlay it
            result = overlay_mask(to_pil_image(img), to_pil_image(activation_map[0].squeeze(), mode='F'), alpha=0.7)
            axs[cur_row, cur_col].imshow(result)
            axs[cur_row, cur_col].axis('off')
            num +=1
        cur_row = int(num / row)
        cur_col = int(num % row)

fig.suptitle("resnet")
plt.savefig(f'al1_grad_cam .jpg', format='jpeg')
plt.show()
print("[Test] accuracy : {:.2f}% [{}/{}]".format(100.*correct/len(test_loader.dataset), correct, len(test_loader.dataset)))
# Out:
# /home/hj/anaconda3/envs/cv/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# cuda
# num of each dataset :  2360 298 296
# test mean ; [0.48197255, 0.49259484, 0.41559336]
# test std : [0.17413613, 0.17235444, 0.18304732]
# /home/hj/anaconda3/envs/cv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hj/anaconda3/envs/cv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─ReLU: 3-3                    --
# |    |    └─Conv2d: 3-4                  36,864
# |    |    └─BatchNorm2d: 3-5             128
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─ReLU: 3-8                    --
# |    |    └─Conv2d: 3-9                  36,864
# |    |    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─ReLU: 3-13                   --
# |    |    └─Conv2d: 3-14                 147,456
# |    |    └─BatchNorm2d: 3-15            256
# |    |    └─Sequential: 3-16             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-17                 147,456
# |    |    └─BatchNorm2d: 3-18            256
# |    |    └─ReLU: 3-19                   --
# |    |    └─Conv2d: 3-20                 147,456
# |    |    └─BatchNorm2d: 3-21            256
# ├─Sequential: 1-7                        --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-22                 294,912
# |    |    └─BatchNorm2d: 3-23            512
# |    |    └─ReLU: 3-24                   --
# |    |    └─Conv2d: 3-25                 589,824
# |    |    └─BatchNorm2d: 3-26            512
# |    |    └─Sequential: 3-27             33,280
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-28                 589,824
# |    |    └─BatchNorm2d: 3-29            512
# |    |    └─ReLU: 3-30                   --
# |    |    └─Conv2d: 3-31                 589,824
# |    |    └─BatchNorm2d: 3-32            512
# ├─Sequential: 1-8                        --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-33                 1,179,648
# |    |    └─BatchNorm2d: 3-34            1,024
# |    |    └─ReLU: 3-35                   --
# |    |    └─Conv2d: 3-36                 2,359,296
# |    |    └─BatchNorm2d: 3-37            1,024
# |    |    └─Sequential: 3-38             132,096
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-39                 2,359,296
# |    |    └─BatchNorm2d: 3-40            1,024
# |    |    └─ReLU: 3-41                   --
# |    |    └─Conv2d: 3-42                 2,359,296
# |    |    └─BatchNorm2d: 3-43            1,024
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           25,650
# =================================================================
# Total params: 11,202,162
# Trainable params: 11,202,162
# Non-trainable params: 0
# =================================================================
#   0%|          | 0/50 [00:00<?, ?it/s]
# Train epoch : 1 [256/2360], learning cost 4.08, avg cost 4.08
# Train epoch : 1 [512/2360], learning cost 4.00, avg cost 4.04
# Train epoch : 1 [768/2360], learning cost 4.02, avg cost 4.04
# Train epoch : 1 [1024/2360], learning cost 4.04, avg cost 4.04
# Train epoch : 1 [1280/2360], learning cost 4.01, avg cost 4.03
# Train epoch : 1 [1536/2360], learning cost 4.00, avg cost 4.03
# Train epoch : 1 [1792/2360], learning cost 3.94, avg cost 4.01
# Train epoch : 1 [2048/2360], learning cost 3.90, avg cost 4.00
# Train epoch : 1 [2304/2360], learning cost 3.90, avg cost 3.99
# Train epoch : 1 [2360/2360], learning cost 3.92, avg cost 3.98
# Test accuracy : 4.05% [12.0/296] 	 Test cost : 3.92
#   2%|▏         | 1/50 [00:27<22:24, 27.43s/it]
# Train epoch : 2 [256/2360], learning cost 3.89, avg cost 3.89
# Train epoch : 2 [512/2360], learning cost 3.87, avg cost 3.88
# Train epoch : 2 [768/2360], learning cost 3.83, avg cost 3.86
# Train epoch : 2 [1024/2360], learning cost 3.84, avg cost 3.86
# Train epoch : 2 [1280/2360], learning cost 3.80, avg cost 3.85
# Train epoch : 2 [1536/2360], learning cost 3.81, avg cost 3.84
# Train epoch : 2 [1792/2360], learning cost 3.83, avg cost 3.84
# Train epoch : 2 [2048/2360], learning cost 3.77, avg cost 3.83
# Train epoch : 2 [2304/2360], learning cost 3.76, avg cost 3.82
# Train epoch : 2 [2360/2360], learning cost 3.74, avg cost 3.81
#   4%|▍         | 2/50 [00:54<21:57, 27.45s/it]
# Test accuracy : 7.09% [21.0/296] 	 Test cost : 3.78
# Train epoch : 3 [256/2360], learning cost 3.67, avg cost 3.67
# Train epoch : 3 [512/2360], learning cost 3.69, avg cost 3.68
# Train epoch : 3 [768/2360], learning cost 3.70, avg cost 3.69
# Train epoch : 3 [1024/2360], learning cost 3.72, avg cost 3.70
# Train epoch : 3 [1280/2360], learning cost 3.68, avg cost 3.69
# Train epoch : 3 [1536/2360], learning cost 3.64, avg cost 3.68
# Train epoch : 3 [1792/2360], learning cost 3.62, avg cost 3.67
# Train epoch : 3 [2048/2360], learning cost 3.61, avg cost 3.67
# Train epoch : 3 [2304/2360], learning cost 3.55, avg cost 3.65
# Train epoch : 3 [2360/2360], learning cost 3.63, avg cost 3.65
#   6%|▌         | 3/50 [01:21<21:18, 27.21s/it]
# Test accuracy : 5.07% [15.0/296] 	 Test cost : 3.78
# Train epoch : 4 [256/2360], learning cost 3.78, avg cost 3.78
# Train epoch : 4 [512/2360], learning cost 3.53, avg cost 3.66
# Train epoch : 4 [768/2360], learning cost 3.40, avg cost 3.57
# Train epoch : 4 [1024/2360], learning cost 3.51, avg cost 3.56
# Train epoch : 4 [1280/2360], learning cost 3.58, avg cost 3.56
# Train epoch : 4 [1536/2360], learning cost 3.50, avg cost 3.55
# Train epoch : 4 [1792/2360], learning cost 3.42, avg cost 3.53
# Train epoch : 4 [2048/2360], learning cost 3.35, avg cost 3.51
# Train epoch : 4 [2304/2360], learning cost 3.39, avg cost 3.50
# Train epoch : 4 [2360/2360], learning cost 3.42, avg cost 3.49
# Test accuracy : 10.14% [30.0/296] 	 Test cost : 3.53
#   8%|▊         | 4/50 [01:49<20:51, 27.21s/it]
# Train epoch : 5 [256/2360], learning cost 3.42, avg cost 3.42
# Train epoch : 5 [512/2360], learning cost 3.38, avg cost 3.40
# Train epoch : 5 [768/2360], learning cost 3.33, avg cost 3.38
# Train epoch : 5 [1024/2360], learning cost 3.26, avg cost 3.35
# Train epoch : 5 [1280/2360], learning cost 3.14, avg cost 3.31
# Train epoch : 5 [1536/2360], learning cost 3.19, avg cost 3.29
# Train epoch : 5 [1792/2360], learning cost 3.18, avg cost 3.27
# Train epoch : 5 [2048/2360], learning cost 3.24, avg cost 3.27
# Train epoch : 5 [2304/2360], learning cost 3.18, avg cost 3.26
# Train epoch : 5 [2360/2360], learning cost 3.48, avg cost 3.28
#  10%|█         | 5/50 [02:15<20:15, 27.02s/it]
# Test accuracy : 5.07% [15.0/296] 	 Test cost : 3.99
# Train epoch : 6 [256/2360], learning cost 3.99, avg cost 3.99
# Train epoch : 6 [512/2360], learning cost 3.79, avg cost 3.89
# Train epoch : 6 [768/2360], learning cost 3.63, avg cost 3.80
# Train epoch : 6 [1024/2360], learning cost 3.56, avg cost 3.74
# Train epoch : 6 [1280/2360], learning cost 3.34, avg cost 3.66
# Train epoch : 6 [1536/2360], learning cost 3.27, avg cost 3.59
# Train epoch : 6 [1792/2360], learning cost 3.57, avg cost 3.59
# Train epoch : 6 [2048/2360], learning cost 3.52, avg cost 3.58
# Train epoch : 6 [2304/2360], learning cost 3.39, avg cost 3.56
# Train epoch : 6 [2360/2360], learning cost 3.52, avg cost 3.56
#  12%|█▏        | 6/50 [02:42<19:48, 27.01s/it]
# Test accuracy : 12.16% [36.0/296] 	 Test cost : 3.59
# Train epoch : 7 [256/2360], learning cost 3.57, avg cost 3.57
# Train epoch : 7 [512/2360], learning cost 3.22, avg cost 3.39
# Train epoch : 7 [768/2360], learning cost 3.02, avg cost 3.27
# Train epoch : 7 [1024/2360], learning cost 2.97, avg cost 3.19
# Train epoch : 7 [1280/2360], learning cost 2.93, avg cost 3.14
# Train epoch : 7 [1536/2360], learning cost 3.07, avg cost 3.13
# Train epoch : 7 [1792/2360], learning cost 3.05, avg cost 3.12
# Train epoch : 7 [2048/2360], learning cost 3.41, avg cost 3.15
# Train epoch : 7 [2304/2360], learning cost 3.24, avg cost 3.16
# Train epoch : 7 [2360/2360], learning cost 3.08, avg cost 3.16
#  14%|█▍        | 7/50 [03:10<19:29, 27.19s/it]
# Test accuracy : 20.95% [62.0/296] 	 Test cost : 3.07
# Train epoch : 8 [256/2360], learning cost 2.86, avg cost 2.86
# Train epoch : 8 [512/2360], learning cost 2.70, avg cost 2.78
# Train epoch : 8 [768/2360], learning cost 2.77, avg cost 2.78
# Train epoch : 8 [1024/2360], learning cost 2.86, avg cost 2.80
# Train epoch : 8 [1280/2360], learning cost 2.70, avg cost 2.78
# Train epoch : 8 [1536/2360], learning cost 3.02, avg cost 2.82
# Train epoch : 8 [1792/2360], learning cost 3.12, avg cost 2.86
# Train epoch : 8 [2048/2360], learning cost 2.99, avg cost 2.88
# Train epoch : 8 [2304/2360], learning cost 2.54, avg cost 2.84
# Train epoch : 8 [2360/2360], learning cost 2.90, avg cost 2.84
#  16%|█▌        | 8/50 [03:37<19:03, 27.22s/it]
# Test accuracy : 16.89% [50.0/296] 	 Test cost : 3.21
# Train epoch : 9 [256/2360], learning cost 2.85, avg cost 2.85
# Train epoch : 9 [512/2360], learning cost 2.69, avg cost 2.77
# Train epoch : 9 [768/2360], learning cost 2.27, avg cost 2.60
# Train epoch : 9 [1024/2360], learning cost 2.53, avg cost 2.58
# Train epoch : 9 [1280/2360], learning cost 3.28, avg cost 2.72
# Train epoch : 9 [1536/2360], learning cost 3.89, avg cost 2.92
# Train epoch : 9 [1792/2360], learning cost 2.95, avg cost 2.92
# Train epoch : 9 [2048/2360], learning cost 2.68, avg cost 2.89
# Train epoch : 9 [2304/2360], learning cost 2.60, avg cost 2.86
# Train epoch : 9 [2360/2360], learning cost 2.25, avg cost 2.80
#  18%|█▊        | 9/50 [04:04<18:34, 27.19s/it]
# Test accuracy : 18.24% [54.0/296] 	 Test cost : 3.44
# Train epoch : 10 [256/2360], learning cost 3.35, avg cost 3.35
# Train epoch : 10 [512/2360], learning cost 3.04, avg cost 3.20
# Train epoch : 10 [768/2360], learning cost 2.93, avg cost 3.11
# Train epoch : 10 [1024/2360], learning cost 2.75, avg cost 3.02
# Train epoch : 10 [1280/2360], learning cost 2.28, avg cost 2.87
# Train epoch : 10 [1536/2360], learning cost 2.54, avg cost 2.82
# Train epoch : 10 [1792/2360], learning cost 3.22, avg cost 2.87
# Train epoch : 10 [2048/2360], learning cost 3.04, avg cost 2.89
# Train epoch : 10 [2304/2360], learning cost 2.71, avg cost 2.87
# Train epoch : 10 [2360/2360], learning cost 2.37, avg cost 2.82
# Test accuracy : 30.74% [91.0/296] 	 Test cost : 2.54
#  20%|██        | 10/50 [04:32<18:14, 27.36s/it]
# Train epoch : 11 [256/2360], learning cost 2.38, avg cost 2.38
# Train epoch : 11 [512/2360], learning cost 2.69, avg cost 2.53
# Train epoch : 11 [768/2360], learning cost 2.51, avg cost 2.53
# Train epoch : 11 [1024/2360], learning cost 2.34, avg cost 2.48
# Train epoch : 11 [1280/2360], learning cost 2.86, avg cost 2.56
# Train epoch : 11 [1536/2360], learning cost 2.38, avg cost 2.53
# Train epoch : 11 [1792/2360], learning cost 2.23, avg cost 2.48
# Train epoch : 11 [2048/2360], learning cost 2.19, avg cost 2.45
# Train epoch : 11 [2304/2360], learning cost 2.63, avg cost 2.47
# Train epoch : 11 [2360/2360], learning cost 2.50, avg cost 2.47
#  22%|██▏       | 11/50 [04:59<17:47, 27.37s/it]
# Test accuracy : 29.39% [87.0/296] 	 Test cost : 2.36
# Train epoch : 12 [256/2360], learning cost 2.18, avg cost 2.18
# Train epoch : 12 [512/2360], learning cost 2.23, avg cost 2.21
# Train epoch : 12 [768/2360], learning cost 2.16, avg cost 2.19
# Train epoch : 12 [1024/2360], learning cost 2.38, avg cost 2.24
# Train epoch : 12 [1280/2360], learning cost 1.95, avg cost 2.18
# Train epoch : 12 [1536/2360], learning cost 1.67, avg cost 2.10
# Train epoch : 12 [1792/2360], learning cost 1.56, avg cost 2.02
# Train epoch : 12 [2048/2360], learning cost 1.47, avg cost 1.95
# Train epoch : 12 [2304/2360], learning cost 1.96, avg cost 1.95
# Train epoch : 12 [2360/2360], learning cost 2.13, avg cost 1.97
#  24%|██▍       | 12/50 [05:27<17:18, 27.33s/it]
# Test accuracy : 34.46% [102.0/296] 	 Test cost : 2.38
# Train epoch : 13 [256/2360], learning cost 2.26, avg cost 2.26
# Train epoch : 13 [512/2360], learning cost 1.98, avg cost 2.12
# Train epoch : 13 [768/2360], learning cost 1.80, avg cost 2.01
# Train epoch : 13 [1024/2360], learning cost 1.44, avg cost 1.87
# Train epoch : 13 [1280/2360], learning cost 1.39, avg cost 1.77
# Train epoch : 13 [1536/2360], learning cost 1.75, avg cost 1.77
# Train epoch : 13 [1792/2360], learning cost 2.00, avg cost 1.80
# Train epoch : 13 [2048/2360], learning cost 1.53, avg cost 1.77
# Train epoch : 13 [2304/2360], learning cost 1.51, avg cost 1.74
# Train epoch : 13 [2360/2360], learning cost 2.08, avg cost 1.77
#  26%|██▌       | 13/50 [05:53<16:43, 27.12s/it]
# Test accuracy : 18.92% [56.0/296] 	 Test cost : 3.11
# Train epoch : 14 [256/2360], learning cost 3.03, avg cost 3.03
# Train epoch : 14 [512/2360], learning cost 2.43, avg cost 2.73
# Train epoch : 14 [768/2360], learning cost 2.08, avg cost 2.51
# Train epoch : 14 [1024/2360], learning cost 1.99, avg cost 2.38
# Train epoch : 14 [1280/2360], learning cost 1.92, avg cost 2.29
# Train epoch : 14 [1536/2360], learning cost 2.17, avg cost 2.27
# Train epoch : 14 [1792/2360], learning cost 2.80, avg cost 2.35
# Train epoch : 14 [2048/2360], learning cost 1.94, avg cost 2.30
# Train epoch : 14 [2304/2360], learning cost 1.61, avg cost 2.22
# Train epoch : 14 [2360/2360], learning cost 1.08, avg cost 2.11
# Test accuracy : 44.93% [133.0/296] 	 Test cost : 2.05
#  28%|██▊       | 14/50 [06:21<16:18, 27.19s/it]
# Train epoch : 15 [256/2360], learning cost 1.75, avg cost 1.75
# Train epoch : 15 [512/2360], learning cost 2.48, avg cost 2.12
# Train epoch : 15 [768/2360], learning cost 1.89, avg cost 2.04
# Train epoch : 15 [1024/2360], learning cost 1.52, avg cost 1.91
# Train epoch : 15 [1280/2360], learning cost 1.22, avg cost 1.77
# Train epoch : 15 [1536/2360], learning cost 1.30, avg cost 1.69
# Train epoch : 15 [1792/2360], learning cost 1.88, avg cost 1.72
# Train epoch : 15 [2048/2360], learning cost 2.59, avg cost 1.83
# Train epoch : 15 [2304/2360], learning cost 2.04, avg cost 1.85
# Train epoch : 15 [2360/2360], learning cost 1.06, avg cost 1.77
#  30%|███       | 15/50 [06:48<15:52, 27.21s/it]
# Test accuracy : 60.14% [178.0/296] 	 Test cost : 1.51
# Train epoch : 16 [256/2360], learning cost 1.33, avg cost 1.33
# Train epoch : 16 [512/2360], learning cost 1.25, avg cost 1.29
# Train epoch : 16 [768/2360], learning cost 1.06, avg cost 1.21
# Train epoch : 16 [1024/2360], learning cost 0.99, avg cost 1.16
# Train epoch : 16 [1280/2360], learning cost 1.06, avg cost 1.14
# Train epoch : 16 [1536/2360], learning cost 1.12, avg cost 1.13
# Train epoch : 16 [1792/2360], learning cost 1.00, avg cost 1.11
# Train epoch : 16 [2048/2360], learning cost 1.07, avg cost 1.11
# Train epoch : 16 [2304/2360], learning cost 0.81, avg cost 1.08
# Train epoch : 16 [2360/2360], learning cost 0.65, avg cost 1.03
#  32%|███▏      | 16/50 [07:15<15:20, 27.07s/it]
# Test accuracy : 50.34% [149.0/296] 	 Test cost : 1.76
# Train epoch : 17 [256/2360], learning cost 1.47, avg cost 1.47
# Train epoch : 17 [512/2360], learning cost 2.54, avg cost 2.01
# Train epoch : 17 [768/2360], learning cost 1.64, avg cost 1.88
# Train epoch : 17 [1024/2360], learning cost 1.38, avg cost 1.76
# Train epoch : 17 [1280/2360], learning cost 0.80, avg cost 1.57
# Train epoch : 17 [1536/2360], learning cost 0.76, avg cost 1.43
# Train epoch : 17 [1792/2360], learning cost 0.75, avg cost 1.33
# Train epoch : 17 [2048/2360], learning cost 0.84, avg cost 1.27
# Train epoch : 17 [2304/2360], learning cost 1.22, avg cost 1.27
# Train epoch : 17 [2360/2360], learning cost 1.14, avg cost 1.25
#  34%|███▍      | 17/50 [07:41<14:49, 26.96s/it]
# Test accuracy : 44.26% [131.0/296] 	 Test cost : 1.81
# Train epoch : 18 [256/2360], learning cost 1.57, avg cost 1.57
# Train epoch : 18 [512/2360], learning cost 2.00, avg cost 1.79
# Train epoch : 18 [768/2360], learning cost 1.15, avg cost 1.57
# Train epoch : 18 [1024/2360], learning cost 0.79, avg cost 1.38
# Train epoch : 18 [1280/2360], learning cost 0.95, avg cost 1.29
# Train epoch : 18 [1536/2360], learning cost 1.29, avg cost 1.29
# Train epoch : 18 [1792/2360], learning cost 1.16, avg cost 1.27
# Train epoch : 18 [2048/2360], learning cost 0.88, avg cost 1.22
# Train epoch : 18 [2304/2360], learning cost 0.79, avg cost 1.18
# Train epoch : 18 [2360/2360], learning cost 0.59, avg cost 1.12
#  36%|███▌      | 18/50 [08:09<14:26, 27.07s/it]
# Test accuracy : 71.62% [212.0/296] 	 Test cost : 1.02
# Train epoch : 19 [256/2360], learning cost 0.62, avg cost 0.62
# Train epoch : 19 [512/2360], learning cost 0.80, avg cost 0.71
# Train epoch : 19 [768/2360], learning cost 0.79, avg cost 0.74
# Train epoch : 19 [1024/2360], learning cost 0.56, avg cost 0.69
# Train epoch : 19 [1280/2360], learning cost 0.78, avg cost 0.71
# Train epoch : 19 [1536/2360], learning cost 1.03, avg cost 0.76
# Train epoch : 19 [1792/2360], learning cost 1.55, avg cost 0.87
# Train epoch : 19 [2048/2360], learning cost 0.79, avg cost 0.86
# Train epoch : 19 [2304/2360], learning cost 0.53, avg cost 0.83
# Train epoch : 19 [2360/2360], learning cost 0.57, avg cost 0.80
#  38%|███▊      | 19/50 [08:35<13:55, 26.94s/it]
# Test accuracy : 69.26% [205.0/296] 	 Test cost : 1.11
# Train epoch : 20 [256/2360], learning cost 0.88, avg cost 0.88
# Train epoch : 20 [512/2360], learning cost 1.03, avg cost 0.95
# Train epoch : 20 [768/2360], learning cost 0.84, avg cost 0.92
# Train epoch : 20 [1024/2360], learning cost 0.62, avg cost 0.84
# Train epoch : 20 [1280/2360], learning cost 0.55, avg cost 0.78
# Train epoch : 20 [1536/2360], learning cost 0.53, avg cost 0.74
# Train epoch : 20 [1792/2360], learning cost 0.62, avg cost 0.72
# Train epoch : 20 [2048/2360], learning cost 0.68, avg cost 0.72
# Train epoch : 20 [2304/2360], learning cost 0.75, avg cost 0.72
# Train epoch : 20 [2360/2360], learning cost 0.75, avg cost 0.72
#  40%|████      | 20/50 [09:02<13:30, 27.02s/it]
# Test accuracy : 59.80% [177.0/296] 	 Test cost : 1.31
# Train epoch : 21 [256/2360], learning cost 1.05, avg cost 1.05
# Train epoch : 21 [512/2360], learning cost 0.93, avg cost 0.99
# Train epoch : 21 [768/2360], learning cost 0.75, avg cost 0.91
# Train epoch : 21 [1024/2360], learning cost 0.54, avg cost 0.82
# Train epoch : 21 [1280/2360], learning cost 0.53, avg cost 0.76
# Train epoch : 21 [1536/2360], learning cost 0.40, avg cost 0.70
# Train epoch : 21 [1792/2360], learning cost 0.44, avg cost 0.66
# Train epoch : 21 [2048/2360], learning cost 0.45, avg cost 0.64
# Train epoch : 21 [2304/2360], learning cost 0.42, avg cost 0.61
# Train epoch : 21 [2360/2360], learning cost 0.67, avg cost 0.62
#  42%|████▏     | 21/50 [09:30<13:05, 27.10s/it]
# Test accuracy : 52.36% [155.0/296] 	 Test cost : 1.84
# Train epoch : 22 [256/2360], learning cost 1.36, avg cost 1.36
# Train epoch : 22 [512/2360], learning cost 1.65, avg cost 1.50
# Train epoch : 22 [768/2360], learning cost 0.98, avg cost 1.33
# Train epoch : 22 [1024/2360], learning cost 0.58, avg cost 1.14
# Train epoch : 22 [1280/2360], learning cost 0.57, avg cost 1.03
# Train epoch : 22 [1536/2360], learning cost 0.35, avg cost 0.91
# Train epoch : 22 [1792/2360], learning cost 0.26, avg cost 0.82
# Train epoch : 22 [2048/2360], learning cost 0.35, avg cost 0.76
# Train epoch : 22 [2304/2360], learning cost 0.21, avg cost 0.70
# Train epoch : 22 [2360/2360], learning cost 0.38, avg cost 0.67
#  44%|████▍     | 22/50 [09:57<12:38, 27.10s/it]
# Test accuracy : 64.19% [190.0/296] 	 Test cost : 1.57
# Train epoch : 23 [256/2360], learning cost 0.99, avg cost 0.99
# Train epoch : 23 [512/2360], learning cost 1.86, avg cost 1.43
# Train epoch : 23 [768/2360], learning cost 1.28, avg cost 1.38
# Train epoch : 23 [1024/2360], learning cost 0.88, avg cost 1.25
# Train epoch : 23 [1280/2360], learning cost 0.55, avg cost 1.11
# Train epoch : 23 [1536/2360], learning cost 0.44, avg cost 1.00
# Train epoch : 23 [1792/2360], learning cost 0.37, avg cost 0.91
# Train epoch : 23 [2048/2360], learning cost 0.37, avg cost 0.84
# Train epoch : 23 [2304/2360], learning cost 0.36, avg cost 0.79
# Train epoch : 23 [2360/2360], learning cost 0.37, avg cost 0.75
#  46%|████▌     | 23/50 [10:24<12:09, 27.03s/it]
# Test accuracy : 68.58% [203.0/296] 	 Test cost : 1.20
# Train epoch : 24 [256/2360], learning cost 0.79, avg cost 0.79
# Train epoch : 24 [512/2360], learning cost 0.63, avg cost 0.71
# Train epoch : 24 [768/2360], learning cost 0.45, avg cost 0.62
# Train epoch : 24 [1024/2360], learning cost 0.31, avg cost 0.54
# Train epoch : 24 [1280/2360], learning cost 0.27, avg cost 0.49
# Train epoch : 24 [1536/2360], learning cost 0.28, avg cost 0.45
# Train epoch : 24 [1792/2360], learning cost 0.28, avg cost 0.43
# Train epoch : 24 [2048/2360], learning cost 0.37, avg cost 0.42
# Train epoch : 24 [2304/2360], learning cost 0.36, avg cost 0.41
# Train epoch : 24 [2360/2360], learning cost 0.29, avg cost 0.40
#  48%|████▊     | 24/50 [10:51<11:46, 27.16s/it]
# Test accuracy : 73.99% [219.0/296] 	 Test cost : 0.82
# Train epoch : 25 [256/2360], learning cost 0.40, avg cost 0.40
# Train epoch : 25 [512/2360], learning cost 0.49, avg cost 0.44
# Train epoch : 25 [768/2360], learning cost 0.41, avg cost 0.43
# Train epoch : 25 [1024/2360], learning cost 0.41, avg cost 0.43
# Train epoch : 25 [1280/2360], learning cost 0.36, avg cost 0.41
# Train epoch : 25 [1536/2360], learning cost 0.33, avg cost 0.40
# Train epoch : 25 [1792/2360], learning cost 0.36, avg cost 0.39
# Train epoch : 25 [2048/2360], learning cost 0.24, avg cost 0.38
# Train epoch : 25 [2304/2360], learning cost 0.22, avg cost 0.36
# Train epoch : 25 [2360/2360], learning cost 0.28, avg cost 0.35
#  50%|█████     | 25/50 [11:18<11:17, 27.10s/it]
# Test accuracy : 72.64% [215.0/296] 	 Test cost : 0.87
# Train epoch : 26 [256/2360], learning cost 0.32, avg cost 0.32
# Train epoch : 26 [512/2360], learning cost 0.27, avg cost 0.29
# Train epoch : 26 [768/2360], learning cost 0.15, avg cost 0.25
# Train epoch : 26 [1024/2360], learning cost 0.16, avg cost 0.23
# Train epoch : 26 [1280/2360], learning cost 0.20, avg cost 0.22
# Train epoch : 26 [1536/2360], learning cost 0.19, avg cost 0.21
# Train epoch : 26 [1792/2360], learning cost 0.24, avg cost 0.22
# Train epoch : 26 [2048/2360], learning cost 0.24, avg cost 0.22
# Train epoch : 26 [2304/2360], learning cost 0.32, avg cost 0.23
# Train epoch : 26 [2360/2360], learning cost 0.29, avg cost 0.24
#  52%|█████▏    | 26/50 [11:45<10:51, 27.15s/it]
# Test accuracy : 78.72% [233.0/296] 	 Test cost : 0.68
# Train epoch : 27 [256/2360], learning cost 0.25, avg cost 0.25
# Train epoch : 27 [512/2360], learning cost 0.22, avg cost 0.23
# Train epoch : 27 [768/2360], learning cost 0.20, avg cost 0.22
# Train epoch : 27 [1024/2360], learning cost 0.25, avg cost 0.23
# Train epoch : 27 [1280/2360], learning cost 0.16, avg cost 0.22
# Train epoch : 27 [1536/2360], learning cost 0.25, avg cost 0.22
# Train epoch : 27 [1792/2360], learning cost 0.14, avg cost 0.21
# Train epoch : 27 [2048/2360], learning cost 0.14, avg cost 0.20
# Train epoch : 27 [2304/2360], learning cost 0.15, avg cost 0.20
# Train epoch : 27 [2360/2360], learning cost 0.18, avg cost 0.19
#  54%|█████▍    | 27/50 [12:12<10:24, 27.14s/it]
# Test accuracy : 76.01% [225.0/296] 	 Test cost : 0.79
# Train epoch : 28 [256/2360], learning cost 0.28, avg cost 0.28
# Train epoch : 28 [512/2360], learning cost 0.24, avg cost 0.26
# Train epoch : 28 [768/2360], learning cost 0.17, avg cost 0.23
# Train epoch : 28 [1024/2360], learning cost 0.17, avg cost 0.21
# Train epoch : 28 [1280/2360], learning cost 0.19, avg cost 0.21
# Train epoch : 28 [1536/2360], learning cost 0.38, avg cost 0.24
# Train epoch : 28 [1792/2360], learning cost 0.46, avg cost 0.27
# Train epoch : 28 [2048/2360], learning cost 0.58, avg cost 0.31
# Train epoch : 28 [2304/2360], learning cost 0.42, avg cost 0.32
# Train epoch : 28 [2360/2360], learning cost 0.24, avg cost 0.31
#  56%|█████▌    | 28/50 [12:39<09:54, 27.00s/it]
# Test accuracy : 73.31% [217.0/296] 	 Test cost : 0.85
# Train epoch : 29 [256/2360], learning cost 0.38, avg cost 0.38
# Train epoch : 29 [512/2360], learning cost 0.34, avg cost 0.36
# Train epoch : 29 [768/2360], learning cost 0.15, avg cost 0.29
# Train epoch : 29 [1024/2360], learning cost 0.13, avg cost 0.25
# Train epoch : 29 [1280/2360], learning cost 0.14, avg cost 0.23
# Train epoch : 29 [1536/2360], learning cost 0.12, avg cost 0.21
# Train epoch : 29 [1792/2360], learning cost 0.11, avg cost 0.20
# Train epoch : 29 [2048/2360], learning cost 0.10, avg cost 0.18
# Train epoch : 29 [2304/2360], learning cost 0.09, avg cost 0.17
# Train epoch : 29 [2360/2360], learning cost 0.16, avg cost 0.17
#  58%|█████▊    | 29/50 [13:07<09:31, 27.20s/it]
# Test accuracy : 84.80% [251.0/296] 	 Test cost : 0.57
# Train epoch : 30 [256/2360], learning cost 0.11, avg cost 0.11
# Train epoch : 30 [512/2360], learning cost 0.16, avg cost 0.14
# Train epoch : 30 [768/2360], learning cost 0.14, avg cost 0.14
# Train epoch : 30 [1024/2360], learning cost 0.21, avg cost 0.16
# Train epoch : 30 [1280/2360], learning cost 0.15, avg cost 0.15
# Train epoch : 30 [1536/2360], learning cost 0.10, avg cost 0.15
# Train epoch : 30 [1792/2360], learning cost 0.10, avg cost 0.14
# Train epoch : 30 [2048/2360], learning cost 0.13, avg cost 0.14
# Train epoch : 30 [2304/2360], learning cost 0.12, avg cost 0.13
# Train epoch : 30 [2360/2360], learning cost 0.16, avg cost 0.14
#  60%|██████    | 30/50 [13:34<09:01, 27.10s/it]
# Test accuracy : 71.28% [211.0/296] 	 Test cost : 1.15
# Train epoch : 31 [256/2360], learning cost 0.71, avg cost 0.71
# Train epoch : 31 [512/2360], learning cost 0.17, avg cost 0.44
# Train epoch : 31 [768/2360], learning cost 0.23, avg cost 0.37
# Train epoch : 31 [1024/2360], learning cost 0.25, avg cost 0.34
# Train epoch : 31 [1280/2360], learning cost 0.15, avg cost 0.30
# Train epoch : 31 [1536/2360], learning cost 0.21, avg cost 0.29
# Train epoch : 31 [1792/2360], learning cost 0.11, avg cost 0.26
# Train epoch : 31 [2048/2360], learning cost 0.13, avg cost 0.24
# Train epoch : 31 [2304/2360], learning cost 0.09, avg cost 0.23
# Train epoch : 31 [2360/2360], learning cost 0.08, avg cost 0.21
#  62%|██████▏   | 31/50 [14:01<08:34, 27.10s/it]
# Test accuracy : 83.78% [248.0/296] 	 Test cost : 0.53
# Train epoch : 32 [256/2360], learning cost 0.08, avg cost 0.08
# Train epoch : 32 [512/2360], learning cost 0.07, avg cost 0.08
# Train epoch : 32 [768/2360], learning cost 0.08, avg cost 0.08
# Train epoch : 32 [1024/2360], learning cost 0.06, avg cost 0.07
# Train epoch : 32 [1280/2360], learning cost 0.07, avg cost 0.07
# Train epoch : 32 [1536/2360], learning cost 0.10, avg cost 0.08
# Train epoch : 32 [1792/2360], learning cost 0.08, avg cost 0.08
# Train epoch : 32 [2048/2360], learning cost 0.08, avg cost 0.08
# Train epoch : 32 [2304/2360], learning cost 0.05, avg cost 0.08
# Train epoch : 32 [2360/2360], learning cost 0.10, avg cost 0.08
#  64%|██████▍   | 32/50 [14:28<08:07, 27.11s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.52
# Train epoch : 33 [256/2360], learning cost 0.07, avg cost 0.07
# Train epoch : 33 [512/2360], learning cost 0.07, avg cost 0.07
# Train epoch : 33 [768/2360], learning cost 0.07, avg cost 0.07
# Train epoch : 33 [1024/2360], learning cost 0.06, avg cost 0.07
# Train epoch : 33 [1280/2360], learning cost 0.06, avg cost 0.07
# Train epoch : 33 [1536/2360], learning cost 0.05, avg cost 0.07
# Train epoch : 33 [1792/2360], learning cost 0.05, avg cost 0.06
# Train epoch : 33 [2048/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 33 [2304/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 33 [2360/2360], learning cost 0.05, avg cost 0.06
#  66%|██████▌   | 33/50 [14:55<07:40, 27.09s/it]
# Test accuracy : 83.78% [248.0/296] 	 Test cost : 0.52
# Train epoch : 34 [256/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 34 [512/2360], learning cost 0.05, avg cost 0.06
# Train epoch : 34 [768/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 34 [1024/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 34 [1280/2360], learning cost 0.05, avg cost 0.06
# Train epoch : 34 [1536/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 34 [1792/2360], learning cost 0.07, avg cost 0.06
# Train epoch : 34 [2048/2360], learning cost 0.05, avg cost 0.06
# Train epoch : 34 [2304/2360], learning cost 0.04, avg cost 0.06
# Train epoch : 34 [2360/2360], learning cost 0.04, avg cost 0.05
#  68%|██████▊   | 34/50 [15:22<07:13, 27.09s/it]
# Test accuracy : 82.77% [245.0/296] 	 Test cost : 0.53
# Train epoch : 35 [256/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 35 [512/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 35 [768/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 35 [1024/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 35 [1280/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 35 [1536/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 35 [1792/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 35 [2048/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 35 [2304/2360], learning cost 0.07, avg cost 0.05
# Train epoch : 35 [2360/2360], learning cost 0.06, avg cost 0.05
#  70%|███████   | 35/50 [15:49<06:47, 27.14s/it]
# Test accuracy : 82.43% [244.0/296] 	 Test cost : 0.54
# Train epoch : 36 [256/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 36 [512/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 36 [768/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 36 [1024/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 36 [1280/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 36 [1536/2360], learning cost 0.08, avg cost 0.05
# Train epoch : 36 [1792/2360], learning cost 0.07, avg cost 0.05
# Train epoch : 36 [2048/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 36 [2304/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 36 [2360/2360], learning cost 0.09, avg cost 0.05
#  72%|███████▏  | 36/50 [16:16<06:20, 27.15s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.55
# Train epoch : 37 [256/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 37 [512/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 37 [768/2360], learning cost 0.07, avg cost 0.05
# Train epoch : 37 [1024/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 37 [1280/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 37 [1536/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 37 [1792/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 37 [2048/2360], learning cost 0.03, avg cost 0.05
# Train epoch : 37 [2304/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 37 [2360/2360], learning cost 0.03, avg cost 0.05
#  74%|███████▍  | 37/50 [16:44<05:53, 27.20s/it]
# Test accuracy : 82.77% [245.0/296] 	 Test cost : 0.55
# Train epoch : 38 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 38 [512/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 38 [768/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 38 [1024/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 38 [1280/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 38 [1536/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 38 [1792/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 38 [2048/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 38 [2304/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 38 [2360/2360], learning cost 0.06, avg cost 0.05
#  76%|███████▌  | 38/50 [17:11<05:25, 27.13s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.56
# Train epoch : 39 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 39 [512/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 39 [768/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 39 [1024/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 39 [1280/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 39 [1536/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 39 [1792/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 39 [2048/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 39 [2304/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 39 [2360/2360], learning cost 0.02, avg cost 0.04
#  78%|███████▊  | 39/50 [17:37<04:56, 26.98s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.56
# Train epoch : 40 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 40 [512/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 40 [768/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 40 [1024/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 40 [1280/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 40 [1536/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 40 [1792/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 40 [2048/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 40 [2304/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 40 [2360/2360], learning cost 0.01, avg cost 0.04
#  80%|████████  | 40/50 [18:04<04:29, 26.95s/it]
# Test accuracy : 83.45% [247.0/296] 	 Test cost : 0.57
# Train epoch : 41 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 41 [512/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 41 [768/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 41 [1024/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 41 [1280/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 41 [1536/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 41 [1792/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 41 [2048/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 41 [2304/2360], learning cost 0.02, avg cost 0.04
# Train epoch : 41 [2360/2360], learning cost 0.03, avg cost 0.04
#  82%|████████▏ | 41/50 [18:31<04:02, 26.97s/it]
# Test accuracy : 83.45% [247.0/296] 	 Test cost : 0.56
# Train epoch : 42 [256/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 42 [512/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 42 [768/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 42 [1024/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 42 [1280/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 42 [1536/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 42 [1792/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 42 [2048/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 42 [2304/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 42 [2360/2360], learning cost 0.02, avg cost 0.04
#  84%|████████▍ | 42/50 [18:58<03:35, 26.99s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.57
# Train epoch : 43 [256/2360], learning cost 0.05, avg cost 0.05
# Train epoch : 43 [512/2360], learning cost 0.06, avg cost 0.05
# Train epoch : 43 [768/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 43 [1024/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 43 [1280/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 43 [1536/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 43 [1792/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 43 [2048/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 43 [2304/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 43 [2360/2360], learning cost 0.02, avg cost 0.04
#  86%|████████▌ | 43/50 [19:25<03:09, 27.05s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.58
# Train epoch : 44 [256/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 44 [512/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 44 [768/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 44 [1024/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 44 [1280/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 44 [1536/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 44 [1792/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 44 [2048/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 44 [2304/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 44 [2360/2360], learning cost 0.02, avg cost 0.04
#  88%|████████▊ | 44/50 [19:53<02:42, 27.06s/it]
# Test accuracy : 83.45% [247.0/296] 	 Test cost : 0.58
# Train epoch : 45 [256/2360], learning cost 0.02, avg cost 0.02
# Train epoch : 45 [512/2360], learning cost 0.02, avg cost 0.02
# Train epoch : 45 [768/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 45 [1024/2360], learning cost 0.05, avg cost 0.03
# Train epoch : 45 [1280/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 45 [1536/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 45 [1792/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 45 [2048/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 45 [2304/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 45 [2360/2360], learning cost 0.05, avg cost 0.04
#  90%|█████████ | 45/50 [20:19<02:15, 27.00s/it]
# Test accuracy : 82.77% [245.0/296] 	 Test cost : 0.60
# Train epoch : 46 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 46 [512/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 46 [768/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 46 [1024/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 46 [1280/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 46 [1536/2360], learning cost 0.02, avg cost 0.03
# Train epoch : 46 [1792/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 46 [2048/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 46 [2304/2360], learning cost 0.06, avg cost 0.04
# Train epoch : 46 [2360/2360], learning cost 0.02, avg cost 0.03
#  92%|█████████▏| 46/50 [20:46<01:47, 26.99s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.59
# Train epoch : 47 [256/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 47 [512/2360], learning cost 0.05, avg cost 0.04
# Train epoch : 47 [768/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 47 [1024/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 47 [1280/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 47 [1536/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 47 [1792/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 47 [2048/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 47 [2304/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 47 [2360/2360], learning cost 0.02, avg cost 0.03
#  94%|█████████▍| 47/50 [21:13<01:20, 27.00s/it]
# Test accuracy : 82.77% [245.0/296] 	 Test cost : 0.59
# Train epoch : 48 [256/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 48 [512/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 48 [768/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 48 [1024/2360], learning cost 0.02, avg cost 0.03
# Train epoch : 48 [1280/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 48 [1536/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 48 [1792/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 48 [2048/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 48 [2304/2360], learning cost 0.06, avg cost 0.03
# Train epoch : 48 [2360/2360], learning cost 0.03, avg cost 0.03
#  96%|█████████▌| 48/50 [21:41<00:54, 27.06s/it]
# Test accuracy : 83.11% [246.0/296] 	 Test cost : 0.60
# Train epoch : 49 [256/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 49 [512/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 49 [768/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 49 [1024/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 49 [1280/2360], learning cost 0.02, avg cost 0.03
# Train epoch : 49 [1536/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 49 [1792/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 49 [2048/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 49 [2304/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 49 [2360/2360], learning cost 0.03, avg cost 0.03
#  98%|█████████▊| 49/50 [22:07<00:26, 26.88s/it]
# Test accuracy : 82.09% [243.0/296] 	 Test cost : 0.60
# Train epoch : 50 [256/2360], learning cost 0.06, avg cost 0.06
# Train epoch : 50 [512/2360], learning cost 0.04, avg cost 0.05
# Train epoch : 50 [768/2360], learning cost 0.02, avg cost 0.04
# Train epoch : 50 [1024/2360], learning cost 0.04, avg cost 0.04
# Train epoch : 50 [1280/2360], learning cost 0.03, avg cost 0.04
# Train epoch : 50 [1536/2360], learning cost 0.03, avg cost 0.03
# Train epoch : 50 [1792/2360], learning cost 0.02, avg cost 0.03
# Train epoch : 50 [2048/2360], learning cost 0.02, avg cost 0.03
# Train epoch : 50 [2304/2360], learning cost 0.04, avg cost 0.03
# Train epoch : 50 [2360/2360], learning cost 0.02, avg cost 0.03
# 100%|██████████| 50/50 [22:34<00:00, 27.09s/it]
# Test accuracy : 82.43% [244.0/296] 	 Test cost : 0.60
# Elasped Time : 0h, 22m, 34s
# Finished Training
# WARNING:root:no value was provided for `target_layer`, thus set to 'layer4'.
# start eval
# torch.Size([1, 3, 448, 448])
# [Test] accuracy : 78.86% [235.0/298]
